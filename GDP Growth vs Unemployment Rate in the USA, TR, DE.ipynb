# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/-gdp-growth-per-year/gdp-growth.xls
# /kaggle/input/unemployment-rate/data1.xls

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # OBSERVING THE DATASET1

# %%
gdp=pd.read_excel('/kaggle/input/-gdp-growth-per-year/gdp-growth.xls')
gdp
# Out:
#            Data Source World Development Indicators             Unnamed: 2  \
# 0    Last Updated Date          2019-12-20 00:00:00                    NaN
# 1                  NaN                          NaN                    NaN
# 2         Country Name                 Country Code         Indicator Name
# 3                Aruba                          ABW  GDP growth (annual %)
# 4          Afghanistan                          AFG  GDP growth (annual %)
# ..                 ...                          ...                    ...
# 262             Kosovo                          XKX  GDP growth (annual %)
# 263        Yemen, Rep.                          YEM  GDP growth (annual %)
# 264       South Africa                          ZAF  GDP growth (annual %)
# 265             Zambia                          ZMB  GDP growth (annual %)
# 266           Zimbabwe                          ZWE  GDP growth (annual %)
#
#             Unnamed: 3  Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 0                  NaN         NaN          NaN          NaN          NaN
# 1                  NaN         NaN          NaN          NaN          NaN
# 2       Indicator Code      1960.0  1961.000000  1962.000000  1963.000000
# 3    NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 4    NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# ..                 ...         ...          ...          ...          ...
# 262  NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 263  NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 264  NY.GDP.MKTP.KD.ZG         NaN     3.844751     6.177883     7.373613
# 265  NY.GDP.MKTP.KD.ZG         NaN     1.361382    -2.490839     3.272393
# 266  NY.GDP.MKTP.KD.ZG         NaN     6.316157     1.434471     6.244345
#
#       Unnamed: 8   Unnamed: 9  ...  Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0            NaN          NaN  ...          NaN          NaN          NaN
# 1            NaN          NaN  ...          NaN          NaN          NaN
# 2    1964.000000  1965.000000  ...  2010.000000  2011.000000  2012.000000
# 3            NaN          NaN  ...    -3.685030     3.446055    -1.369863
# 4            NaN          NaN  ...    14.362441     0.426355    12.752287
# ..           ...          ...  ...          ...          ...          ...
# 262          NaN          NaN  ...     3.308633     4.377008     2.809626
# 263          NaN          NaN  ...     7.702307   -12.714897     2.392990
# 264     7.939782     6.122761  ...     3.039731     3.284168     2.213355
# 265    12.214048    16.647456  ...    10.298206     5.564625     7.597617
# 266    -1.106172     4.910571  ...    19.675323    14.193913    16.665429
#
#      Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2    2013.000000  2014.000000  2015.000000  2016.000000  2017.000000
# 3       4.198232     0.848228    -0.450586    -0.211225     1.330511
# 4       5.600745     2.724543     1.451315     2.260314     2.665292
# ..           ...          ...          ...          ...          ...
# 262     3.441469     1.222803     4.095281     4.070292     4.226087
# 263     4.823519    -0.188690   -16.678463   -13.621458    -5.942320
# 264     2.485201     1.846992     1.193733     0.399088     1.414513
# 265     5.059376     4.695826     2.919881     3.757178     3.403169
# 266     1.989493     2.376929     1.779873     0.755869     4.704035
#
#      Unnamed: 62  Unnamed: 63
# 0            NaN          NaN
# 1            NaN          NaN
# 2    2018.000000       2019.0
# 3            NaN          NaN
# 4       1.030660          NaN
# ..           ...          ...
# 262     3.813314          NaN
# 263    -2.701475          NaN
# 264     0.787056          NaN
# 265     3.794901          NaN
# 266     6.159190          NaN
#
# [267 rows x 64 columns]

# %%
gdp[2::]
# Out:
#       Data Source World Development Indicators             Unnamed: 2  \
# 2    Country Name                 Country Code         Indicator Name
# 3           Aruba                          ABW  GDP growth (annual %)
# 4     Afghanistan                          AFG  GDP growth (annual %)
# 5          Angola                          AGO  GDP growth (annual %)
# 6         Albania                          ALB  GDP growth (annual %)
# ..            ...                          ...                    ...
# 262        Kosovo                          XKX  GDP growth (annual %)
# 263   Yemen, Rep.                          YEM  GDP growth (annual %)
# 264  South Africa                          ZAF  GDP growth (annual %)
# 265        Zambia                          ZMB  GDP growth (annual %)
# 266      Zimbabwe                          ZWE  GDP growth (annual %)
#
#             Unnamed: 3  Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 2       Indicator Code      1960.0  1961.000000  1962.000000  1963.000000
# 3    NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 4    NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 5    NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 6    NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# ..                 ...         ...          ...          ...          ...
# 262  NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 263  NY.GDP.MKTP.KD.ZG         NaN          NaN          NaN          NaN
# 264  NY.GDP.MKTP.KD.ZG         NaN     3.844751     6.177883     7.373613
# 265  NY.GDP.MKTP.KD.ZG         NaN     1.361382    -2.490839     3.272393
# 266  NY.GDP.MKTP.KD.ZG         NaN     6.316157     1.434471     6.244345
#
#       Unnamed: 8   Unnamed: 9  ...  Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 2    1964.000000  1965.000000  ...  2010.000000  2011.000000  2012.000000
# 3            NaN          NaN  ...    -3.685030     3.446055    -1.369863
# 4            NaN          NaN  ...    14.362441     0.426355    12.752287
# 5            NaN          NaN  ...     4.859220     3.471981     8.542147
# 6            NaN          NaN  ...     3.706891     2.545323     1.417524
# ..           ...          ...  ...          ...          ...          ...
# 262          NaN          NaN  ...     3.308633     4.377008     2.809626
# 263          NaN          NaN  ...     7.702307   -12.714897     2.392990
# 264     7.939782     6.122761  ...     3.039731     3.284168     2.213355
# 265    12.214048    16.647456  ...    10.298206     5.564625     7.597617
# 266    -1.106172     4.910571  ...    19.675323    14.193913    16.665429
#
#      Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 2    2013.000000  2014.000000  2015.000000  2016.000000  2017.000000
# 3       4.198232     0.848228    -0.450586    -0.211225     1.330511
# 4       5.600745     2.724543     1.451315     2.260314     2.665292
# 5       4.954590     4.822626     0.943576    -2.580097    -0.147207
# 6       1.001989     1.774487     2.218751     3.314805     3.821081
# ..           ...          ...          ...          ...          ...
# 262     3.441469     1.222803     4.095281     4.070292     4.226087
# 263     4.823519    -0.188690   -16.678463   -13.621458    -5.942320
# 264     2.485201     1.846992     1.193733     0.399088     1.414513
# 265     5.059376     4.695826     2.919881     3.757178     3.403169
# 266     1.989493     2.376929     1.779873     0.755869     4.704035
#
#      Unnamed: 62  Unnamed: 63
# 2    2018.000000       2019.0
# 3            NaN          NaN
# 4       1.030660          NaN
# 5      -2.133493          NaN
# 6       4.145238          NaN
# ..           ...          ...
# 262     3.813314          NaN
# 263    -2.701475          NaN
# 264     0.787056          NaN
# 265     3.794901          NaN
# 266     6.159190          NaN
#
# [265 rows x 64 columns]

# %% [markdown]
# Adjusting data form to our interest situation

# %%
gdp = gdp[(gdp['Data Source'] == 'Turkey')  | (gdp['Data Source'] == 'Germany') |  (gdp['Data Source'] == 'United States')]

# %%
gdp.drop(columns =['World Development Indicators', 'Unnamed: 2',
       'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
       'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
       'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
       'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
       'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
       'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
       'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
       'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
       'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
       'Unnamed: 53', 'Unnamed: 63'], inplace = True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
gdp
# Out:
#        Data Source  Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  \
# 56         Germany     4.178969     3.924133     0.419551     0.428243
# 245         Turkey     8.487372    11.113496     4.789940     8.491309
# 252  United States     2.563767     1.550836     2.249546     1.842081
#
#      Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62
# 56      2.225689     1.739750     2.230000     2.465030     1.527446
# 245     5.166691     6.085887     3.183832     7.470867     2.826776
# 252     2.451973     2.880910     1.567215     2.217010     2.927323

# %%
gdp.rename(columns = {'Data Source':'Year', 'Unnamed: 54' : '2010', 'Unnamed: 55': '2011', 'Unnamed: 56': '2012', 'Unnamed: 57': '2013', 'Unnamed: 58': '2014', 'Unnamed: 59': '2015', 'Unnamed: 60': '2016', 'Unnamed: 61': '2017', 'Unnamed: 62': '2018'}, inplace= True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
gdp.set_index(keys = ['Year'], inplace = True)
gdp
# Out:
#                    2010       2011      2012      2013      2014      2015  \
# Year
# Germany        4.178969   3.924133  0.419551  0.428243  2.225689  1.739750
# Turkey         8.487372  11.113496  4.789940  8.491309  5.166691  6.085887
# United States  2.563767   1.550836  2.249546  1.842081  2.451973  2.880910
#
#                    2016      2017      2018
# Year
# Germany        2.230000  2.465030  1.527446
# Turkey         3.183832  7.470867  2.826776
# United States  1.567215  2.217010  2.927323

# %%
gdp = gdp.T
gdp
# Out:
# Year   Germany     Turkey  United States
# 2010  4.178969   8.487372       2.563767
# 2011  3.924133  11.113496       1.550836
# 2012  0.419551   4.789940       2.249546
# 2013  0.428243   8.491309       1.842081
# 2014  2.225689   5.166691       2.451973
# 2015  1.739750   6.085887       2.880910
# 2016  2.230000   3.183832       1.567215
# 2017  2.465030   7.470867       2.217010
# 2018  1.527446   2.826776       2.927323

# %% [markdown]
# # BASIC PLOT FOR DATASET1

# %%
gdp.plot(colormap= 'Set3', figsize = (10,6), lw = 4);
plt.xlabel('Years')
plt.ylabel('GDP Growth %')
plt.title('GDP Growth of Some Countries')
# Out:
# Text(0.5, 1.0, 'GDP Growth of Some Countries')

# %% [markdown]
# # Getting the Dataset2

# %%
unemp = pd.read_excel('/kaggle/input/unemployment-rate/data1.xls')
unemp
# Out:
#            Data Source World Development Indicators  \
# 0    Last Updated Date          2019-12-20 00:00:00
# 1                  NaN                          NaN
# 2         Country Name                 Country Code
# 3                Aruba                          ABW
# 4          Afghanistan                          AFG
# ..                 ...                          ...
# 262             Kosovo                          XKX
# 263        Yemen, Rep.                          YEM
# 264       South Africa                          ZAF
# 265             Zambia                          ZMB
# 266           Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                       Indicator Name  Indicator Code
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# ..                                                 ...             ...
# 262  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 263  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 264  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 265  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 266  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2        1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 262         NaN         NaN         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN         NaN         NaN
# 264         NaN         NaN         NaN         NaN         NaN         NaN
# 265         NaN         NaN         NaN         NaN         NaN         NaN
# 266         NaN         NaN         NaN         NaN         NaN         NaN
#
#      ...  Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 0    ...          NaN          NaN          NaN          NaN          NaN
# 1    ...          NaN          NaN          NaN          NaN          NaN
# 2    ...  2010.000000     2011.000     2012.000     2013.000  2014.000000
# 3    ...          NaN          NaN          NaN          NaN          NaN
# 4    ...     2.275000        1.984        1.692        1.725     1.735000
# ..   ...          ...          ...          ...          ...          ...
# 262  ...          NaN          NaN          NaN          NaN          NaN
# 263  ...    12.905000       13.058       13.252       13.507    13.467000
# 264  ...    24.693001       24.653       24.732       24.569    24.898001
# 265  ...    13.190000       10.200        7.850        7.801     7.707000
# 266  ...     5.122000        5.368        5.608        5.623     5.518000
#
#      Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2       2015.000  2016.000000     2017.000     2018.000  2019.000000
# 3            NaN          NaN          NaN          NaN          NaN
# 4          1.679     1.634000        1.559        1.542     1.519000
# ..           ...          ...          ...          ...          ...
# 262          NaN          NaN          NaN          NaN          NaN
# 263       14.023    13.524000       13.175       12.934    12.809000
# 264       25.156    26.551001       27.327       26.958    27.320999
# 265        7.446     7.372000        7.206        7.209     7.145000
# 266        5.438     5.239000        4.943        4.915     4.898000
#
# [267 rows x 64 columns]

# %% [markdown]
# Transforming the dataset style that I wanted to observe

# %%
unemp = unemp[(unemp['Data Source'] == 'Turkey')  | (unemp['Data Source'] == 'Germany') |  (unemp['Data Source'] == 'United States')]
unemp
# Out:
#        Data Source World Development Indicators  \
# 56         Germany                          DEU
# 245         Turkey                          TUR
# 252  United States                          USA
#
#                                             Unnamed: 2      Unnamed: 3  \
# 56   Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 245  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 252  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 56          NaN         NaN         NaN         NaN         NaN         NaN
# 245         NaN         NaN         NaN         NaN         NaN         NaN
# 252         NaN         NaN         NaN         NaN         NaN         NaN
#
#      ...  Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 56   ...        6.966        5.824        5.379        5.231        4.981
# 245  ...       10.660        8.796        8.149        8.732        9.880
# 252  ...        9.633        8.949        8.069        7.375        6.168
#
#      Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63
# 56         4.624        4.122        3.746        3.425        3.199
# 245       10.236       10.839       10.819       10.895       11.895
# 252        5.280        4.869        4.355        3.933        3.869
#
# [3 rows x 64 columns]

# %%
unemp.drop(columns = ['World Development Indicators', 'Unnamed: 2',
       'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
       'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
       'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
       'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
       'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
       'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
       'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
       'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
       'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
       'Unnamed: 53', 'Unnamed: 63'], inplace = True)
unemp
# Out:
#        Data Source  Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  \
# 56         Germany        6.966        5.824        5.379        5.231
# 245         Turkey       10.660        8.796        8.149        8.732
# 252  United States        9.633        8.949        8.069        7.375
#
#      Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62
# 56         4.981        4.624        4.122        3.746        3.425
# 245        9.880       10.236       10.839       10.819       10.895
# 252        6.168        5.280        4.869        4.355        3.933

# %%
unemp.rename(columns = {'Data Source':'Year', 'Unnamed: 54' : '2010', 'Unnamed: 55': '2011', 'Unnamed: 56': '2012', 'Unnamed: 57': '2013', 'Unnamed: 58': '2014', 'Unnamed: 59': '2015', 'Unnamed: 60': '2016', 'Unnamed: 61': '2017', 'Unnamed: 62': '2018'}, inplace= True)

# %%
unemp.set_index(keys = ['Year'], inplace = True)

# %%
unemp = unemp.T
unemp
# Out:
# Year  Germany  Turkey  United States
# 2010    6.966  10.660          9.633
# 2011    5.824   8.796          8.949
# 2012    5.379   8.149          8.069
# 2013    5.231   8.732          7.375
# 2014    4.981   9.880          6.168
# 2015    4.624  10.236          5.280
# 2016    4.122  10.839          4.869
# 2017    3.746  10.819          4.355
# 2018    3.425  10.895          3.933

# %% [markdown]
# # Basic Plot

# %%
unemp.plot(colormap= 'Set3', figsize = (10,6), lw = 4);
plt.xlabel('Years')
plt.ylabel('Unemployment Rate')
plt.title('Unemploymant Rate % Per Year')
# Out:
# Text(0.5, 1.0, 'Unemploymant Rate % Per Year')

# %% [markdown]
# # SUBPLOT

# %% [markdown]
# Combining 2 graphics

# %%
fig, ax1= plt.subplots(figsize=(15,5))
ax1.plot(gdp.index, gdp['Germany'],'-s' ,label ='Germany GDP') # -s means square.
ax1.plot(gdp.index, gdp['Turkey'], '-s', label = 'Turkey GDP')
ax1.plot(gdp.index, gdp['United States'],'-s', label = 'US GDP')
ax1.set_xlabel('Year')
ax1.set_ylabel('GDP Growth %')
ax1.tick_params('y')
ax1.legend(loc='lower left')

 
ax2 = ax1.twinx() # observing datasets in same years so we are using same x labels
ax2.plot(unemp.index, unemp['Germany'], '-x', label ='Germany UNEMP')
ax2.plot(unemp.index, unemp['Turkey'], '-x', label = 'Turkey UNEMP')
ax2.plot(unemp.index, unemp['United States'],'-x', label = 'US UNEMP')
ax2.set_ylabel('Unemployment Rate Per Year')
ax2.tick_params('y')
ax2.legend(loc='upper right', bbox_to_anchor=(1, 0.85)) # You can adjust your legend location with bbox_to_anchor.
plt.title('% GDP Growth vs Unemployment Rate %')
fig.tight_layout()
plt.show()
